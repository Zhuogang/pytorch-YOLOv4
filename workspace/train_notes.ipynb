# %%
# import requests


# def download_file_from_google_drive(id, destination):
#     data = {'export': 'download', 'confirm': 't'}
#     response = requests.post('https://drive.google.com/uc?id=1wv_LiFeCRYwtpkqREPeI13-gPELBDwuJ', data=data)
#     save_response_content(response, destination)
 
# def save_response_content(response, destination):
#     CHUNK_SIZE = 32768
#     with open(destination, "wb") as f:
#         for chunk in response.iter_content(CHUNK_SIZE):
#             if chunk:  # filter out keep-alive new chunks
#                 f.write(chunk)

# download_file_from_google_drive('1wv_LiFeCRYwtpkqREPeI13-gPELBDwuJ', './yolo_v4.pth')

# %%
# !pip install torchvision
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.1 is available.
# You should consider upgrading via the '/home/zhuogang/yolov4_torch/bin/python3.7 -m pip install --upgrade pip' command.

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# %pwd
# Out:
# '/home/zhuogang/pytorch-YOLOv4/workspace'

# %%
# !python /home/zhuogang/pytorch-YOLOv4/train.py -l 0.001 -pretrained /home/zhuogang/pytorch-YOLOv4/custom_data/checkpoints/Yolov4_epoch61.pth -classes 1 -dir /home/zhuogang/pytorch-YOLOv4/custom_data/QT_coco_data_1024/images
# Out:
# log file path:log/log_2022-05-21_21-41-40.txt
# 2022-05-21 21:41:40,346 train.py[line:644] INFO: Using device cuda
# 2022-05-21 21:41:45,149 train.py[line:353] INFO: Starting training:
#         Epochs:          500
#         Batch size:      1
#         Subdivisions:    1
#         Learning rate:   0.001
#         Training size:   503
#         Validation size: 63
#         Checkpoints:     True
#         Device:          cuda
#         Images size:     1024
#         Optimizer:       adam
#         Dataset classes: 1
#         Train label path:/home/zhuogang/pytorch-YOLOv4/custom_data/QT_coco_data_1024/train.txt
#         Pretrained:
#
# Epoch 1/500:   4%| | 19/503 [00:15<05:28,  1.48img/home/zhuogang/yolov4_torch/lib/python3.7/site-packages/torch/optim/lr_scheduler.py:249: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# ...

# %%
# !tensorboard --logdir log
